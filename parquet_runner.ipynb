# %%
import pandas as pd

# Show full URL text and more rows
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)

# Load the Parquet file
df = pd.read_parquet("2a_ufc_events.parquet")

# Display the first 100 rows
print(df.head(100))

# Print total number of URLs
print(f"Total URLs loaded: {len(df)}")
# Out:
#                                                                            URL
# 0           https://www.tapology.com/fightcenter/events/126286-ufc-fight-night
# 1           https://www.tapology.com/fightcenter/events/127957-ufc-fight-night
# 2           https://www.tapology.com/fightcenter/events/127934-ufc-fight-night
# 3           https://www.tapology.com/fightcenter/events/125931-ufc-fight-night
# 4                   https://www.tapology.com/fightcenter/events/127441-ufc-318
# 5           https://www.tapology.com/fightcenter/events/126523-ufc-fight-night
# 6                   https://www.tapology.com/fightcenter/events/124086-ufc-317
# 7           https://www.tapology.com/fightcenter/events/125838-ufc-fight-night
# 8           https://www.tapology.com/fightcenter/events/125944-ufc-fight-night
# 9                   https://www.tapology.com/fightcenter/events/124620-ufc-316
# 10          https://www.tapology.com/fightcenter/events/123251-ufc-fight-night
# ...

# %%
import pandas as pd

# Show full URL text and more rows
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)

# Load the Parquet file
df = pd.read_parquet("3a_winners.parquet")

# Display the first 100 rows
print(df.head(100))

# Print total number of URLs
print(f"Total URLs loaded: {len(df)}")
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Total URLs loaded: 0
